# %% [markdown]
# # Linear Regression Model

# %%
import pandas as pd
import numpy as np

# %%
niti = pd.read_csv('NITI_DATA.csv')

# %%
niti.head()
# Out:
#    Capital_Receipts  Aggregate_Receipts  Social_Sector_Expenditure  \
# 0             325.0              1590.0                      532.0
# 1             187.0               709.0                      171.0
# 2             702.0              1690.0                      452.0
# 3             345.0              1370.0                      406.0
# 4             116.0               576.0                      137.0
#
#    Interest_Payments  Own_Tax_Revenues  Fiscal_Deficits  \
# 0               81.7             582.0            222.1
# 1               30.0              66.0            -27.4
# 2              107.1             277.0            335.8
# 3               68.6             531.0            246.5
# 4               37.0             234.0            112.0
#
#    Outstanding_Liabilities  Aggregate_Expenditure  Revenue_Receipts  \
# 0                    81.50                 1610.0            1265.0
# 1                    43.41                  758.0             522.0
# 2                   106.33                 1791.0             988.0
# 3                    80.76                 1442.0            1025.0
# 4                    30.76                  607.0             460.0
#
#    Revenue_Expenditure  Revenue_Deficits  Capital_Expenditure  \
# 0               1161.0            -104.0                449.0
# 1                357.0            -165.0                401.0
# 2                929.0             -59.0                862.0
# 3                903.0            -122.0                539.0
# 4                401.0             -59.0                207.0
#
#    Nominal_GSDP_Series
# 0               8191.0
# 1               2516.0
# 2               7353.0
# 3               7427.0
# 4               3386.0

# %%
import matplotlib.pyplot as plt

# %%
niti.head()
# Out:
#    Capital_Receipts  Aggregate_Receipts  Social_Sector_Expenditure  \
# 0             325.0              1590.0                      532.0
# 1             187.0               709.0                      171.0
# 2             702.0              1690.0                      452.0
# 3             345.0              1370.0                      406.0
# 4             116.0               576.0                      137.0
#
#    Interest_Payments  Own_Tax_Revenues  Fiscal_Deficits  \
# 0               81.7             582.0            222.1
# 1               30.0              66.0            -27.4
# 2              107.1             277.0            335.8
# 3               68.6             531.0            246.5
# 4               37.0             234.0            112.0
#
#    Outstanding_Liabilities  Aggregate_Expenditure  Revenue_Receipts  \
# 0                    81.50                 1610.0            1265.0
# 1                    43.41                  758.0             522.0
# 2                   106.33                 1791.0             988.0
# 3                    80.76                 1442.0            1025.0
# 4                    30.76                  607.0             460.0
#
#    Revenue_Expenditure  Revenue_Deficits  Capital_Expenditure  \
# 0               1161.0            -104.0                449.0
# 1                357.0            -165.0                401.0
# 2                929.0             -59.0                862.0
# 3                903.0            -122.0                539.0
# 4                401.0             -59.0                207.0
#
#    Nominal_GSDP_Series
# 0               8191.0
# 1               2516.0
# 2               7353.0
# 3               7427.0
# 4               3386.0

# %%
niti.describe().T
# Out:
#                            count          mean           std      min  \
# Capital_Receipts           660.0   2428.893939   4110.573309 -5116.00
# Aggregate_Receipts         660.0   7791.672727  10883.932609    38.00
# Social_Sector_Expenditure  660.0   2623.565152   3470.775608     9.00
# Interest_Payments          660.0   1060.228030   1757.027349     0.00
# Own_Tax_Revenues           660.0   2604.877273   4224.076558     0.00
# Fiscal_Deficits            660.0   1630.949848   2688.436374  -360.00
# Outstanding_Liabilities    660.0    417.522303    596.079415     1.42
# Aggregate_Expenditure      660.0   7663.422727  10658.752422    43.00
# Revenue_Receipts           660.0   5362.778788   7044.667651    37.00
# Revenue_Expenditure        660.0   6022.030303   8317.578141    30.00
# Revenue_Deficits           660.0    659.255455   1824.575250 -4328.00
# Capital_Expenditure        660.0   1641.445455   2554.712652    13.00
# Nominal_GSDP_Series        660.0  37596.312121  57944.592770    52.00
#
#                                  25%       50%        75%       max
# Capital_Receipts            238.7500    811.50   2583.750   37639.0
# Aggregate_Receipts         1143.5000   3191.50   9882.000   72074.0
# Social_Sector_Expenditure   381.2500   1114.00   3512.000   24268.0
# Interest_Payments            81.7000    290.00   1240.000   11870.0
# Own_Tax_Revenues             90.0000    879.50   3174.750   33540.0
# Fiscal_Deficits             159.9500    517.00   1736.150   18620.0
# Outstanding_Liabilities      49.6725    177.21    505.725    4067.4
# Aggregate_Expenditure      1175.5000   3078.50   9737.250   72668.0
# Revenue_Receipts            892.5000   2347.50   7210.750   48438.0
# Revenue_Expenditure         864.0000   2275.50   7755.000   52280.0
# Revenue_Deficits            -62.3750     41.25    594.675   18583.0
# Capital_Expenditure         289.5000    797.00   1851.750   21622.0
# Nominal_GSDP_Series        2963.0000  14311.00  44635.000  486766.0

# %%
niti.corr()
# Out:
#                            Capital_Receipts  Aggregate_Receipts  \
# Capital_Receipts                   1.000000            0.958102
# Aggregate_Receipts                 0.958102            1.000000
# Social_Sector_Expenditure          0.901525            0.976070
# Interest_Payments                  0.945287            0.955550
# Own_Tax_Revenues                   0.864848            0.946278
# Fiscal_Deficits                    0.939052            0.922980
# Outstanding_Liabilities            0.914235            0.956505
# Aggregate_Expenditure              0.952641            0.996875
# Revenue_Receipts                   0.896756            0.985935
# Revenue_Expenditure                0.931491            0.989615
# Revenue_Deficits                   0.783977            0.704623
# Capital_Expenditure                0.941874            0.937185
# Nominal_GSDP_Series                0.904869            0.956340
#
#                            Social_Sector_Expenditure  Interest_Payments  \
# Capital_Receipts                            0.901525           0.945287
# Aggregate_Receipts                          0.976070           0.955550
# Social_Sector_Expenditure                   1.000000           0.923355
# Interest_Payments                           0.923355           1.000000
# Own_Tax_Revenues                            0.945140           0.856082
# Fiscal_Deficits                             0.916260           0.935745
# Outstanding_Liabilities                     0.948411           0.953921
# Aggregate_Expenditure                       0.978583           0.958109
# Revenue_Receipts                            0.981976           0.924738
# Revenue_Expenditure                         0.983376           0.955489
# Revenue_Deficits                            0.691462           0.785332
# Capital_Expenditure                         0.881187           0.886556
# Nominal_GSDP_Series                         0.951463           0.909927
#
#                            Own_Tax_Revenues  Fiscal_Deficits  \
# Capital_Receipts                   0.864848         0.939052
# Aggregate_Receipts                 0.946278         0.922980
# Social_Sector_Expenditure          0.945140         0.916260
# Interest_Payments                  0.856082         0.935745
# Own_Tax_Revenues                   1.000000         0.847567
# Fiscal_Deficits                    0.847567         1.000000
# Outstanding_Liabilities            0.903109         0.927833
# Aggregate_Expenditure              0.942623         0.936765
# Revenue_Receipts                   0.957349         0.878056
# Revenue_Expenditure                0.942143         0.935389
# Revenue_Deficits                   0.598584         0.873941
# Capital_Expenditure                0.865397         0.862949
# Nominal_GSDP_Series                0.957997         0.904112
#
#                            Outstanding_Liabilities  Aggregate_Expenditure  \
# Capital_Receipts                          0.914235               0.952641
# Aggregate_Receipts                        0.956505               0.996875
# Social_Sector_Expenditure                 0.948411               0.978583
# Interest_Payments                         0.953921               0.958109
# Own_Tax_Revenues                          0.903109               0.942623
# Fiscal_Deficits                           0.927833               0.936765
# Outstanding_Liabilities                   1.000000               0.957928
# Aggregate_Expenditure                     0.957928               1.000000
# Revenue_Receipts                          0.944332               0.984293
# Revenue_Expenditure                       0.964662               0.994104
# Revenue_Deficits                          0.751491               0.731423
# Capital_Expenditure                       0.855936               0.935613
# Nominal_GSDP_Series                       0.954329               0.953906
#
#                            Revenue_Receipts  Revenue_Expenditure  \
# Capital_Receipts                   0.896756             0.931491
# Aggregate_Receipts                 0.985935             0.989615
# Social_Sector_Expenditure          0.981976             0.983376
# Interest_Payments                  0.924738             0.955489
# Own_Tax_Revenues                   0.957349             0.942143
# Fiscal_Deficits                    0.878056             0.935389
# Outstanding_Liabilities            0.944332             0.964662
# Aggregate_Expenditure              0.984293             0.994104
# Revenue_Receipts                   1.000000             0.985418
# Revenue_Expenditure                0.985418             1.000000
# Revenue_Deficits                   0.631183             0.753954
# Capital_Expenditure                0.898356             0.891816
# Nominal_GSDP_Series                0.949542             0.953390
#
#                            Revenue_Deficits  Capital_Expenditure  \
# Capital_Receipts                   0.783977             0.941874
# Aggregate_Receipts                 0.704623             0.937185
# Social_Sector_Expenditure          0.691462             0.881187
# Interest_Payments                  0.785332             0.886556
# Own_Tax_Revenues                   0.598584             0.865397
# Fiscal_Deficits                    0.873941             0.862949
# Outstanding_Liabilities            0.751491             0.855936
# Aggregate_Expenditure              0.731423             0.935613
# Revenue_Receipts                   0.631183             0.898356
# Revenue_Expenditure                0.753954             0.891816
# Revenue_Deficits                   1.000000             0.596941
# Capital_Expenditure                0.596941             1.000000
# Nominal_GSDP_Series                0.679997             0.875852
#
#                            Nominal_GSDP_Series
# Capital_Receipts                      0.904869
# Aggregate_Receipts                    0.956340
# Social_Sector_Expenditure             0.951463
# Interest_Payments                     0.909927
# Own_Tax_Revenues                      0.957997
# Fiscal_Deficits                       0.904112
# Outstanding_Liabilities               0.954329
# Aggregate_Expenditure                 0.953906
# Revenue_Receipts                      0.949542
# Revenue_Expenditure                   0.953390
# Revenue_Deficits                      0.679997
# Capital_Expenditure                   0.875852
# Nominal_GSDP_Series                   1.000000

# %% [markdown]
# # Splitting the Data

# %%
from sklearn.model_selection import train_test_split

# %%
niti['Nominal_GSDP_Series'].hist(bins=30)

# %%
X = niti.iloc[:, 0:-1]

# %%
X.shape
# Out:
# (660, 12)

# %%
X.head()
# Out:
#    Capital_Receipts  Aggregate_Receipts  Social_Sector_Expenditure  \
# 0             325.0              1590.0                      532.0
# 1             187.0               709.0                      171.0
# 2             702.0              1690.0                      452.0
# 3             345.0              1370.0                      406.0
# 4             116.0               576.0                      137.0
#
#    Interest_Payments  Own_Tax_Revenues  Fiscal_Deficits  \
# 0               81.7             582.0            222.1
# 1               30.0              66.0            -27.4
# 2              107.1             277.0            335.8
# 3               68.6             531.0            246.5
# 4               37.0             234.0            112.0
#
#    Outstanding_Liabilities  Aggregate_Expenditure  Revenue_Receipts  \
# 0                    81.50                 1610.0            1265.0
# 1                    43.41                  758.0             522.0
# 2                   106.33                 1791.0             988.0
# 3                    80.76                 1442.0            1025.0
# 4                    30.76                  607.0             460.0
#
#    Revenue_Expenditure  Revenue_Deficits  Capital_Expenditure
# 0               1161.0            -104.0                449.0
# 1                357.0            -165.0                401.0
# 2                929.0             -59.0                862.0
# 3                903.0            -122.0                539.0
# 4                401.0             -59.0                207.0

# %%
Y = niti.iloc[:, -1]

# %%
Y.head()
# Out:
# 0    8191.0
# 1    2516.0
# 2    7353.0
# 3    7427.0
# 4    3386.0
# Name: Nominal_GSDP_Series, dtype: float64

# %%
Y.shape
# Out:
# (660,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# # Model Creation

# %%
from sklearn import datasets, linear_model

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regr.score(X_test, Y_test)
# Out:
# 0.9589428413610699

# %% [markdown]
# # Model Analysing

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
Ya = Y_test
Yp = regr.predict(X_test)
mse = mean_squared_error(Ya, Yp)
R2 = r2_score(Ya, Yp)

# %%
'MSE : {}, RMSE : {}, R2-Score : {}'.format(mse, np.sqrt(mse), R2)
# Out:
# 'MSE : 149350783.38085592, RMSE : 12220.915815963053, R2-Score : 0.9589428413610698'
